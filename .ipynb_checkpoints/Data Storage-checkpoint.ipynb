# %%
import requests
import pandas as pd
import numpy as np
import json
import csv
import itertools
import sys
import config
from config import client_id
import time



#Symbols to retrieve in order to get data
symbols = ["SPY", "IVV", "/ES", "QQQ", "TQQQ", "SQQQ"]

# %%
def getQuotes(symbols_to_use = []):
    endpoint = r"https://api.tdameritrade.com/v1/marketdata/quotes"

    #define our payload
    payload =  {'apikey':client_id,
                'symbol':symbols}

    #make a request
    content = requests.get(url = endpoint, params = payload)
    return content.json()

# %%
def dict_to_CSV(dw = {}):
    for key in dw:
        new_dict = dw[key]
        temp_keys = new_dict.keys()
    
    
    #have to change csv file name because it is \ES 
    if(key == "/ES"):
        csv_file = "data_ES.csv"
    else:
        csv_file = "data_{}.csv".format(key)
        
        
    with open(csv_file, 'w') as f:
        w = csv.DictWriter(f,temp_keys)
        w.writeheader()
        w.writerow(new_dict)

# %%
#Had to Hard Code, change if there is change to symbols.

def make_dataFrames_for_Symbols():
    dict_for_keys = getQuotes(symbols_to_use = symbols)
    
    spy_dict = dict_for_keys["SPY"]
    spy_df = pd.DataFrame(spy_dict.values(), spy_dict.keys())
    
    ivv_dict = dict_for_keys["IVV"]
    ivv_df = pd.DataFrame(ivv_dict.values(), ivv_dict.keys())
    
    es_dict = dict_for_keys["/ES"]
    es_df = pd.DataFrame(es_dict.values(), es_dict.keys())
    
    qqq_dict = dict_for_keys["QQQ"]
    qqq_df = pd.DataFrame(qqq_dict.values(), qqq_dict.keys())
    
    tqqq_dict = dict_for_keys["TQQQ"]
    tqqq_df = pd.DataFrame(tqqq_dict.values(), tqqq_dict.keys())
    
    sqqq_dict = dict_for_keys["SQQQ"]
    sqqq_df = pd.DataFrame(sqqq_dict.values(), sqqq_dict.keys())
    
    return (spy_df, ivv_df, es_df, qqq_df, tqqq_df, sqqq_df)

# %%
def multi_quote():
    spy_df, ivv_df, es_df, qqq_df, tqqq_df, sqqq_df = make_dataFrames_for_Symbols()
    
    #60 x minutes
    #23400 = time market is open from 6:30 to 1:00
    t_end = time.time()+ 23400;
    t_end = time.time() + 30;
    
    #ROW OF DF TO USE, CHANGE BEFORE RUNNING TO PREVENT OVERRIDE
    x = 0
    
    while time.time()< t_end:
        #Get Quote (dict of dict), get single symbol(dict), make df (pd df), add to existing df
        full_size_dict = getQuotes(symbols_to_use = symbols)
        spy_df[x] = full_size_dict['SPY'].values()
        
        ivv_df[x] = full_size_dict['IVV'].values()
        
        es_df[x] = full_size_dict['/ES'].values()
        
        qqq_df[x] = full_size_dict['QQQ'].values()
        
        tqqq_df[x] = full_size_dict['TQQQ'].values()
        
        sqqq_df[x] = full_size_dict['SQQQ'].values()
        
        if x% 25 == 0:
            print("Saving")
            spy_df.to_csv("data_SPY", header = True)
            ivv_df.to_csv("data_IVV", header = True)
            es_df.to_csv("data_ES", header = True)
            qqq_df.to_csv("data_qqq", header = True)
            tqqq_df.to_csv("data_tqqq", header = True)
            sqqq_df.to_csv("data_sqqq", header = True)
        
        x +=1 
        
        time.sleep(1)
        
    return (spy_df, ivv_df, es_df, qqq_df, tqqq_df, sqqq_df)

# %%
if __name__=="__main__":
    spy_df, ivv_df, es_df, qqq_df, tqqq_df, sqqq_df = multi_quote()
    
    spy_df.to_csv("data_SPY", header = True)
    ivv_df.to_csv("data_IVV", header = True)
    es_df.to_csv("data_ES", header = True)
    qqq_df.to_csv("data_qqq", header = True)
    tqqq_df.to_csv("data_tqqq", header = True)
    sqqq_df.to_csv("data_sqqq", header = True)
# Out:
# Saving

# %%
#TEST BLOCK
spy_df.transpose()
# Out:
#    assetType assetMainType      cusip assetSubType symbol   description  \
# 0        ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 1        ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 2        ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 3        ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 4        ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 5        ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 6        ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 7        ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 8        ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 9        ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 10       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 11       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 12       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 13       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 14       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 15       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 16       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 17       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 18       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 19       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 20       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 21       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 22       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
# 23       ETF        EQUITY  78462F103          ETF    SPY  SPDR S&P 500
#
#    bidPrice bidSize bidId askPrice  ... securityStatus regularMarketLastPrice  \
# 0    352.99    1000     P   353.04  ...         Normal                 352.43
# 1    352.99    1000     P   353.04  ...         Normal                 352.43
# 2    352.99    1000     P   353.04  ...         Normal                 352.43
# 3    352.99    1000     P   353.04  ...         Normal                 352.43
# 4    352.99    1000     P   353.04  ...         Normal                 352.43
# 5    352.99    1000     P   353.04  ...         Normal                 352.43
# 6    352.99    1000     P   353.04  ...         Normal                 352.43
# 7    352.99    1000     P   353.04  ...         Normal                 352.43
# 8    352.99    1000     P   353.04  ...         Normal                 352.43
# 9    352.99    1000     P   353.04  ...         Normal                 352.43
# 10   352.99    1000     P   353.04  ...         Normal                 352.43
# 11   352.99    1000     P   353.04  ...         Normal                 352.43
# 12   352.99    1000     P   353.04  ...         Normal                 352.43
# 13   352.99    1000     P   353.04  ...         Normal                 352.43
# 14   352.99    1000     P   353.04  ...         Normal                 352.43
# 15   352.99    1000     P   353.04  ...         Normal                 352.43
# 16   352.99    1000     P   353.04  ...         Normal                 352.43
# 17   352.99    1000     P   353.04  ...         Normal                 352.43
# 18   352.99    1000     P   353.04  ...         Normal                 352.43
# 19   352.99    1000     P   353.04  ...         Normal                 352.43
# 20   352.99    1000     P   353.04  ...         Normal                 352.43
# 21   352.99    1000     P   353.04  ...         Normal                 352.43
# 22   352.99    1000     P   353.04  ...         Normal                 352.43
# 23   352.99    1000     P   353.04  ...         Normal                 352.43
#
#    regularMarketLastSize regularMarketNetChange regularMarketTradeTimeInLong  \
# 0                      8                   5.58                1602547200003
# 1                      8                   5.58                1602547200003
# 2                      8                   5.58                1602547200003
# 3                      8                   5.58                1602547200003
# 4                      8                   5.58                1602547200003
# 5                      8                   5.58                1602547200003
# 6                      8                   5.58                1602547200003
# 7                      8                   5.58                1602547200003
# 8                      8                   5.58                1602547200003
# 9                      8                   5.58                1602547200003
# 10                     8                   5.58                1602547200003
# 11                     8                   5.58                1602547200003
# 12                     8                   5.58                1602547200003
# 13                     8                   5.58                1602547200003
# 14                     8                   5.58                1602547200003
# 15                     8                   5.58                1602547200003
# 16                     8                   5.58                1602547200003
# 17                     8                   5.58                1602547200003
# 18                     8                   5.58                1602547200003
# 19                     8                   5.58                1602547200003
# 20                     8                   5.58                1602547200003
# 21                     8                   5.58                1602547200003
# 22                     8                   5.58                1602547200003
# 23                     8                   5.58                1602547200003
#
#    netPercentChangeInDouble markChangeInDouble markPercentChangeInDouble  \
# 0                    1.6088               5.58                    1.6088
# 1                    1.6088               5.58                    1.6088
# 2                    1.6088               5.58                    1.6088
# 3                    1.6088               5.58                    1.6088
# 4                    1.6088               5.58                    1.6088
# 5                    1.6088               5.58                    1.6088
# 6                    1.6088               5.58                    1.6088
# 7                    1.6088               5.58                    1.6088
# 8                    1.6088               5.58                    1.6088
# 9                    1.6088               5.58                    1.6088
# 10                   1.6088               5.58                    1.6088
# 11                   1.6088               5.58                    1.6088
# 12                   1.6088               5.58                    1.6088
# 13                   1.6088               5.58                    1.6088
# 14                   1.6088               5.58                    1.6088
# 15                   1.6088               5.58                    1.6088
# 16                   1.6088               5.58                    1.6088
# 17                   1.6088               5.58                    1.6088
# 18                   1.6088               5.58                    1.6088
# 19                   1.6088               5.58                    1.6088
# 20                   1.6088               5.58                    1.6088
# 21                   1.6088               5.58                    1.6088
# 22                   1.6088               5.58                    1.6088
# 23                   1.6088               5.58                    1.6088
#
#    regularMarketPercentChangeInDouble delayed
# 0                              1.6088    True
# 1                              1.6088    True
# 2                              1.6088    True
# 3                              1.6088    True
# 4                              1.6088    True
# 5                              1.6088    True
# 6                              1.6088    True
# 7                              1.6088    True
# 8                              1.6088    True
# 9                              1.6088    True
# 10                             1.6088    True
# 11                             1.6088    True
# 12                             1.6088    True
# 13                             1.6088    True
# 14                             1.6088    True
# 15                             1.6088    True
# 16                             1.6088    True
# 17                             1.6088    True
# 18                             1.6088    True
# 19                             1.6088    True
# 20                             1.6088    True
# 21                             1.6088    True
# 22                             1.6088    True
# 23                             1.6088    True
#
# [24 rows x 48 columns]
